# %%
## Arithmethic Operation

a=10
b = 5

add_result=a+b  #addiiton
sub_result=a-b  #substraction 
mult_result=a*b #multiplication
div_result=a/b  #division
floor_div_result=a//b ## floor division
modulus_result=a%b #modulus operation

exponent_result=a**b ## Exponentiation


print(add_result)
print(sub_result)
print(mult_result)
print(div_result)
print(floor_div_result)
print(modulus_result)
print(exponent_result)
# Out:
# 15
# 5
# 50
# 2.0
# 2
# 0
# 100000

# %%
21/5
# Out:
# 4.2

# %%
21//5
# Out:
# 4

# %%
#comparators
#==
a=4
b=5
a==b
# Out:
# False

# %%
b=4
a==b
# Out:
# True

# %%
str1="Ank"
str2="ank"
str1==str2
# Out:
# False

# %%
#greater then

a=5
b=4
a>b
# Out:
# True

# %%
### Logical operator
x=True
y=False

z=x and y #AND operation
z
# Out:
# False

# %%
z=x or y #OR operation
z
# Out:
# True

# %%
z= not y #inverse of boolean variable
z
# Out:
# True
